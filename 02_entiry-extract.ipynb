# %%
# !pip install transformers torch
# !pip install sentencepiece
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 85
dir_process_id = 86

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='covid_round4.json'))
meta
# Out:
# {'owner': 'thanaporn',
#  'human_size': '336.66 KB',
#  'name': 'covid_round4.json',
#  'description': 'file covid_round4.json',
#  'directory': 85,
#  'path': 'thanaporn/DSI310-G3/rawData/covid_round4.json'}

# %%
data = json.load(fp)
data
# Out:
# [{'year': 2021,
#   'weeknum': 52,
#   'province': 'ตรัง',
#   'new_case': 47,
#   'total_case': 18171,
#   'new_case_excludeabroad': 47,
#   'total_case_excludeabroad': 18169,
#   'new_death': 2,
#   'total_death': 117,
#   'update_date': '2022-10-24 07:25:57'},
#  {'year': 2021,
#   'weeknum': 52,
#   'province': 'สกลนคร',
#   'new_case': 7,
#   'total_case': 8055,
#   'new_case_excludeabroad': 7,
#   'total_case_excludeabroad': 8055,
#   'new_death': 0,
#   'total_death': 38,
#   'update_date': '2022-10-24 07:25:57'},
#  {'year': 2021,
#   'weeknum': 52,
#   'province': 'เพชรบุรี',
#   'new_case': 8,
#   'total_case': 24609,
#   'new_case_excludeabroad': 8,
#   'total_case_excludeabroad': 24607,
#   'new_death': 0,
#   'total_death': 155,
#   'update_date': '2022-10-24 07:25:57'},
#  {'year': 2021,
#   'weeknum': 52,
#   'province': 'สมุทรปราการ',
#   'new_case': 84,
#   'total_case': 135879,
#   'new_case_excludeabroad': 76,
#   'total_case_excludeabroad': 135346,
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#      year  weeknum       province  new_case  total_case  \
# 0    2021       52           ตรัง        47       18171
# 1    2021       52         สกลนคร         7        8055
# 2    2021       52       เพชรบุรี         8       24609
# 3    2021       52    สมุทรปราการ        84      135879
# 4    2021       52        สระบุรี        29       34678
# ..    ...      ...            ...       ...         ...
# 995  2022       12        ไม่ระบุ         0         173
# 996  2022       12        นครนายก       864       18290
# 997  2022       12         นครปฐม      3646       62689
# 998  2022       12      กาญจนบุรี      1823       38914
# 999  2022       12  กรุงเทพมหานคร     22935      652079
#
#      new_case_excludeabroad  total_case_excludeabroad  new_death  total_death  \
# 0                        47                     18169          2          117
# 1                         7                      8055          0           38
# ...

# %%
datanode.write(df=df, directory=dir_process_id, name="data", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='covid_round4.json')])
# Out:
# {'sucess': True,
#  'file_id': 85,
#  'path': 'thanaporn/DSI310-G3/processData/data.parquet',
#  'lineage': True}
