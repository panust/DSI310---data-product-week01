# %%
import requests
import json
import pandas as pd

# %%
API_KEY = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjY2ODAzNDIwLCJpYXQiOjE2NjY3MTcwMjAsImp0aSI6Ijk1OTUzMDI0NWUwMDRkNWFiZmIxMzdjNGZiMmEzM2FiIiwidXNlcl9pZCI6MzN9.dg0ROCdCQenMdpdDp1G5J2Mscsvp8nLi6-Gc71xuxGI"
N_PAGE = 10

# %%
url = "https://covid19.ddc.moph.go.th/api/Cases/timeline-cases-by-provinces"
response = requests.get(url=url)
print(response.json())
# Out:
# {'data': [{'year': 2021, 'weeknum': 52, 'province': 'ตรัง', 'new_case': 47, 'total_case': 18171, 'new_case_excludeabroad': 47, 'total_case_excludeabroad': 18169, 'new_death': 2, 'total_death': 117, 'update_date': '2022-10-24 07:25:57'}, {'year': 2021, 'weeknum': 52, 'province': 'สกลนคร', 'new_case': 7, 'total_case': 8055, 'new_case_excludeabroad': 7, 'total_case_excludeabroad': 8055, 'new_death': 0, 'total_death': 38, 'update_date': '2022-10-24 07:25:57'}, {'year': 2021, 'weeknum': 52, 'province': 'เพชรบุรี', 'new_case': 8, 'total_case': 24609, 'new_case_excludeabroad': 8, 'total_case_excludeabroad': 24607, 'new_death': 0, 'total_death': 155, 'update_date': '2022-10-24 07:25:57'}, {'year': 2021, 'weeknum': 52, 'province': 'สมุทรปราการ', 'new_case': 84, 'total_case': 135879, 'new_case_excludeabroad': 76, 'total_case_excludeabroad': 135346, 'new_death': 0, 'total_death': 1487, 'update_date': '2022-10-24 07:25:57'}, {'year': 2021, 'weeknum': 52, 'province': 'สระบุรี', 'new_case': 29, 't
# ...

# %%
with open('covid_round4.json', 'w',encoding='utf8') as outfile:
    json.dump(response.json()['data'], outfile, ensure_ascii=False,indent=4)

# %%
df = pd.json_normalize(response.json()['data']) 
df.to_csv('covid_round4.csv',index=None,encoding='utf-8-sig')

# %%
from dsmlibrary.datanode import DataNode

# %%
dir_raw_id = 85

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
datanode.upload_file(directory_id=dir_raw_id, file_path='covid_round4.json')
# Out:
#   0%|          | 0.00/329k [00:00<?, ?B/s]
# {'id': 72,
#  'msg': 'file covid_round4.json create sucessful',
#  'path': 'thanaporn/DSI310-G3/rawData/covid_round4.json',
#  'uploaded': True}
